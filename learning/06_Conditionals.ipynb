# %% [markdown]
# # Conditionals and Booleans - Corey Shafer Tutorial #6
# Date: June 6, 2026
# Learning: Python's main collection data types

# %%
language = 'Python'

if language == 'Python':
    print('language is Python')
elif language == 'Java':
    print('Language is Java')
else:
    print('No match')
